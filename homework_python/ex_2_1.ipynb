# %% [markdown]
# # NN for the KS equation
# Kuramoto-Sivashinsky eqaution is a foruth-order nonlinear partial diffentali equation. It has been developed to model diffusive-thermal instabilities in a laminar front.

# %%
import numpy as np
from PDE_FIND import *
import scipy.io as sio
import os
import tensorflow as tf
from tensorflow import keras as K
from tensorflow.keras.utils import Sequence
from sklearn.model_selection import train_test_split

# %%
# Loading data
cwd = os.getcwd()

data = sio.loadmat(os.path.join(cwd,'Datasets','kuramoto_sivishinky.mat'))
u = data['uu']
x = data['x'][:,0]
t = data['tt'][0,:]
dt = t[1]-t[0]
dx = x[2]-x[1]

x_len = len(x)
t_len = len(t)

X = np.transpose(u)

# Alla fine il function generator non è stato utilizzato
# class KS_NN(Sequence):
#     """Data generator for the ."""

#     def __init__(self, X_train, *, batch_size=16, shuffle=False, val_split=0.2):
        
#         self.X_train = X_train
#         self.t_len = X.shape[0]
#         self.x_len = X.shape[1]
#         self.shuffle = shuffle 
#         self.batch_size = batch_size
#         #self.on_epoch_end()  # called at the end of every epoch, to shuffle self.X

#     def __len__(self):
#         """Required to define the number of batches per epoch"""
#         return int(np.floor(self.t_len / self.batch_size))
        
#     def on_epoch_end(self):         
#         """Method called at the end of every epoch. If requested, the indeces 
#         are randomly shuffled"""

#         if self.shuffle == True:
#             np.random.shuffle(self.X)

#     def __getitem__(self, index):
#         """Generates one batch of data"""
#         X = self.X_train[index*self.batch_size:(index+1)*self.batch_size-1,:]
#         y = self.X_train[index*self.batch_size+1:(index+1)*self.batch_size,:]

#         return X, y

# %%
# KS_gen = KS_NN(
#     X,
#     batch_size=32, 
#     shuffle=False, 
#     val_split=0.2,
# )

# model = K.Sequential()
# model.add(K.layers.InputLayer(input_shape=(x_len),))
# model.add(K.layers.Dense(500, activation='relu'))
# model.add(K.layers.Dense(200, activation='relu'))
# model.add(K.layers.Dense(500, activation='relu'))
# model.add(K.layers.Dense(x_len, activation='linear'))

X_train = X[:-1,:]
y_train = X[1:,:]

x_in = K.Input(shape=(1024,))
y = K.layers.Dense(500, activation="relu")(x_in)
y = K.layers.Dense(200, activation="relu")(y)
y = K.layers.Dense(500, activation="relu")(y)
y = K.layers.Dense(1024, activation="linear")(y)

model = K.Model(x_in, y)

model.compile(
    optimizer="adam",
    loss="mean_absolute_error",
    metrics=None,
)

# Train model on dataset
train_history = model.fit(#KS_gen,
    x = X_train,
    y = y_train,
    shuffle=True,
    #validation_data=val_generator,
    epochs=500,
    verbose=1,
    use_multiprocessing=True,
    workers=8,
)


model.save(os.path.join("KS_model3"))
# Out:
# Epoch 1/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.6986
# Epoch 2/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4374
# Epoch 3/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3136
# Epoch 4/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2363
# Epoch 5/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1886
# Epoch 6/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1596
# Epoch 7/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1466
# Epoch 8/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1276
# Epoch 9/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1091
# Epoch 10/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0996
# Epoch 11/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0861
# Epoch 12/500
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0807
# ...
